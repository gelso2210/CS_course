# %%
import pandas as pd

# %% [markdown]
# ## Read the titles dataframe

# %%
snl = pd.read_csv('https://github.com/gdv/foundationsCS/raw/main/students/ex-data/snldb/snl_title.csv')
snl.head()
# Out:
#    sid  eid         tid                                     title  \
# 0    3   20  1978052013  "Space is the Place", "Space-Loneliness"
# 1    2   21  1977051416                                       NaN
# 2    3   18  1978042215                                       NaN
# 3    3   20  1978052014                                       NaN
# 4    3   18  1978042214                       Next Week In Review
#
#              titleType
# 0  Musical Performance
# 1           Goodnights
# 2           Goodnights
# 3           Goodnights
# 4                 Show

# %% [markdown]
# ## Remove all rows that do not have a title

# %%
snl.dropna(subset=['title'], inplace=True)
snl.head()
# Out:
#     sid  eid         tid                                     title  \
# 0     3   20  1978052013  "Space is the Place", "Space-Loneliness"
# 4     3   18  1978042214                       Next Week In Review
# 13    2   20  1977042314                    Trans Eastern Airlines
# 15    7   20  1982052214                               "Landslide"
# 17    7   20  1982052215                                 The Clams
#
#               titleType
# 0   Musical Performance
# 4                  Show
# 13               Sketch
# 15  Musical Performance
# 17           Commercial

# %% [markdown]
# ## 2. Build a DataFrame with index the pair (season id, episode id).

# %%
snl2= snl.set_index(['sid', 'eid'])
snl2.head()
# Out:
#                 tid                                     title  \
# sid eid
# 3   20   1978052013  "Space is the Place", "Space-Loneliness"
#     18   1978042214                       Next Week In Review
# 2   20   1977042314                    Trans Eastern Airlines
# 7   20   1982052214                               "Landslide"
#     20   1982052215                                 The Clams
#
#                    titleType
# sid eid
# 3   20   Musical Performance
#     18                  Show
# 2   20                Sketch
# 7   20   Musical Performance
#     20            Commercial

# %% [markdown]
# ## 3. Extract the sketches of seasons 3 and 4.

# %%
snl2.loc[[3,4],].loc[snl2.loc[[3,4],]['titleType']=='Sketch']
# Out:
#                 tid                             title titleType
# sid eid
# 3   18   1978042211                    Troff 'n' Brew    Sketch
#     18    197804229                        Love Story    Sketch
#     18    197804226               Dancing in the Dark    Sketch
#     19    197805138                        Pet Peeves    Sketch
#     19    197805137                      Nick Springs    Sketch
# ...             ...                               ...       ...
# 4   11    197902105             The Shah's Final Days    Sketch
#     14    197903107     Unsung Heroes of Rock 'n Roll    Sketch
#     15    197903178                         Lois Lane    Sketch
#     15    197903176  St. Mickey's Knights of Columbus    Sketch
#     15    197903174      Fred Garvin: Male Prostitute    Sketch
#
# [122 rows x 3 columns]
