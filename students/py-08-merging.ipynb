# %%
import pandas as pd

# %%
snl = pd.read_csv('https://github.com/gdv/foundationsCS/raw/main/students/ex-data/snldb/snl_title.csv')
snl.head()
# Out:
#    sid  eid         tid                                     title  \
# 0    3   20  1978052013  "Space is the Place", "Space-Loneliness"
# 1    2   21  1977051416                                       NaN
# 2    3   18  1978042215                                       NaN
# 3    3   20  1978052014                                       NaN
# 4    3   18  1978042214                       Next Week In Review
#
#              titleType
# 0  Musical Performance
# 1           Goodnights
# 2           Goodnights
# 3           Goodnights
# 4                 Show

# %%
episodes = pd.read_csv('https://github.com/gdv/foundationsCS/raw/main/students/ex-data/snldb/snl_episode.csv', parse_dates=["aired"])
episodes.head()
# Out:
#    sid  eid  year      aired
# 0    3   20  1977 1978-05-20
# 1    3   19  1977 1978-05-13
# 2    3   18  1977 1978-04-22
# 3    2   21  1976 1977-05-14
# 4    2   22  1976 1977-05-21

# %%
seasons = pd.read_csv('https://github.com/gdv/foundationsCS/raw/main/students/ex-data/snldb/snl_season.csv')
seasons.head(50)
# Out:
#     sid  year
# 0     1  1975
# 1     2  1976
# 2     3  1977
# 3     4  1978
# 4     5  1979
# 5     6  1980
# 6     7  1981
# 7     8  1982
# 8     9  1983
# 9    10  1984
# 10   11  1985
# 11   12  1986
# 12   13  1987
# 13   14  1988
# 14   15  1989
# 15   16  1990
# 16   17  1991
# 17   18  1992
# 18   19  1993
# 19   20  1994
# 20   21  1995
# 21   22  1996
# 22   23  1997
# 23   24  1998
# 24   25  1999
# 25   26  2000
# 26   27  2001
# 27   28  2002
# 28   29  2003
# 29   30  2004
# 30   31  2005
# 31   32  2006
# 32   33  2007
# 33   34  2008
# 34   35  2009
# 35   36  2010
# 36   37  2011
# 37   38  2012
# 38   39  2013
# 39   40  2014
# 40   41  2015
# 41   42  2016

# %% [markdown]
# ## Compute the sketches of the season with year 1978

# %% [markdown]
# The condition for selecting the rows is a single equality

# %%
pd.merge(snl[snl.titleType=='Sketch'], seasons[seasons.year==1978], on='sid', how='inner')
# Out:
#     sid  eid         tid                                       title  \
# 0     4   17   197904148                     Farbers Retirement Home
# 1     4   17   197904146                           The Launching Pad
# 2     4   17   197904143                                The Widettes
# 3     4   18  1979051211                         Snyder Mother's Day
# 4     4   18   197905128             Boulevard Of Proud Chicano Cars
# 5     4   19  1979051913                                 Candy Store
# 6     4   19   197905197                           Mother & Daughter
# 7     4   19   197905194                         Houseguest Idi Amin
# 8     4   20  1979052610                            The Olympia Cafe
# 9     4   16   197904078                         Scottish Restaurant
# 10    4   16   197904074                                Nerds & Milt
# 11    4   16   197904073                          The Pepsi Syndrome
# 12    4   14   197903109                                Muck Jumpers
# 13    4    2  1978101410                                Bobbi Farber
# 14    4    2   197810147                                   Five A.M.
# 15    4    2  1978101412                             Scotch Boutique
# 16    4    1  1978100710  A Framework for the Reunion of The Beatles
# 17    4    1   197810076                            The Olympia Cafe
# 18    4    1   197810075                               Nerds / Norge
# 19    4    2   197810144                                   Stunt Man
# 20    4    3   197810217                     Night On Freak Mountain
# 21    4    3   197810213                       The Coneheads At Home
# 22    4    4  1978110412                                  Restaurant
# 23    4    3   197810214                               Baxter Prison
# 24    4    5  1978111112            St. Mickey's Knights of Columbus
# 25    4    5   197811119                                  Nick Sands
# 26    4    6  1978111810                               The World Bar
# 27    4    6   197811184                                 Loud Family
# 28    4    6   197811185                               Mercy Killers
# 29    4    6   197811183        Beach Blanket Bimbo From Outer Space
# 30    4    7  1978120211                               Surplus Store
# 31    4    7   197812028                                The New Dick
# 32    4    7   197812026                                     Bedroom
# 33    4    7   197812024                               Bad News Bees
# 34    4    7   197812025                            The Olympia Cafe
# 35    4    8  1978120912                           Cochise At Oxford
# 36    4    8   197812099                                 Candy Slice
# 37    4    9  1978121612                                  Dubs Trees
# 38    4    9  1978121610            St. Mickey's Knights of Columbus
# 39    4    9   197812168                       Alcoholic's Christmas
# 40    4    9   197812166                              Mommie Dearest
# 41    4    9   197812164                                The Widettes
# 42    4   12   197902179                                 Barber Shop
# 43    4   12   197902173                           The Twilight Zone
# 44    4   12   197902174                      Rock Against Yeast '79
# 45    4   13  1979022413                 The Coneheads At The Movies
# 46    4   13   197902245                          Child Psychiatrist
# 47    4   13   197902244                     Fred Silverman's Office
# 48    4   13   197902243                           Nerds & The Nurse
# 49    4   11  1979021012                                    X-Police
# 50    4   11   197902109                                  Nick Rails
# 51    4   11   197902104                                The Widettes
# 52    4   11   197902105                       The Shah's Final Days
# 53    4   14   197903107               Unsung Heroes of Rock 'n Roll
# 54    4   15   197903178                                   Lois Lane
# 55    4   15   197903176            St. Mickey's Knights of Columbus
# 56    4   15   197903174                Fred Garvin: Male Prostitute
#
#    titleType  year
# 0     Sketch  1978
# 1     Sketch  1978
# 2     Sketch  1978
# 3     Sketch  1978
# 4     Sketch  1978
# 5     Sketch  1978
# 6     Sketch  1978
# 7     Sketch  1978
# 8     Sketch  1978
# 9     Sketch  1978
# 10    Sketch  1978
# 11    Sketch  1978
# 12    Sketch  1978
# 13    Sketch  1978
# 14    Sketch  1978
# 15    Sketch  1978
# 16    Sketch  1978
# 17    Sketch  1978
# 18    Sketch  1978
# 19    Sketch  1978
# 20    Sketch  1978
# 21    Sketch  1978
# 22    Sketch  1978
# 23    Sketch  1978
# 24    Sketch  1978
# 25    Sketch  1978
# 26    Sketch  1978
# 27    Sketch  1978
# 28    Sketch  1978
# 29    Sketch  1978
# 30    Sketch  1978
# 31    Sketch  1978
# 32    Sketch  1978
# 33    Sketch  1978
# 34    Sketch  1978
# 35    Sketch  1978
# 36    Sketch  1978
# 37    Sketch  1978
# 38    Sketch  1978
# 39    Sketch  1978
# 40    Sketch  1978
# 41    Sketch  1978
# 42    Sketch  1978
# 43    Sketch  1978
# 44    Sketch  1978
# 45    Sketch  1978
# 46    Sketch  1978
# 47    Sketch  1978
# 48    Sketch  1978
# 49    Sketch  1978
# 50    Sketch  1978
# 51    Sketch  1978
# 52    Sketch  1978
# 53    Sketch  1978
# 54    Sketch  1978
# 55    Sketch  1978
# 56    Sketch  1978

# %% [markdown]
# ## Compute the sketches of the seasons with year 1978-1982

# %%
pd.merge(snl[snl.titleType=='Sketch'], seasons[(seasons.year==1978) | (seasons.year==1982) ], on='sid', how='inner')
# Out:
#      sid  eid         tid                              title titleType  year
# 0      4   17   197904148            Farbers Retirement Home    Sketch  1978
# 1      4   17   197904146                  The Launching Pad    Sketch  1978
# 2      4   17   197904143                       The Widettes    Sketch  1978
# 3      4   18  1979051211                Snyder Mother's Day    Sketch  1978
# 4      4   18   197905128    Boulevard Of Proud Chicano Cars    Sketch  1978
# ..   ...  ...         ...                                ...       ...   ...
# 124    8   14   198302264                             Pimple    Sketch  1982
# 125    8   15  1983031217                        Songwriters    Sketch  1982
# 126    8   15  1983031215      Jerry Lewis School of Manners    Sketch  1982
# 127    8   15  1983031213                     Veggie Burgers    Sketch  1982
# 128    8   15   198303126  The Home For Disgusting Practices    Sketch  1982
#
# [129 rows x 6 columns]

# %% [markdown]
# In this case the condition of the selection is more complex and requires the conjuction of two different conditions.
# The precedence order betweeen operators implies that we have to use the parenthesis.

# %% [markdown]
# ## Compute the sketches aired in 1978 (consider the table snl_episode.csv)

# %% [markdown]
# First we merge the episodes with the snl dataframe, so that we have the air date of each sketch.

# %%
pd.merge(episodes[episodes.aired.dt.year== 1978], snl[snl.titleType=='Sketch'], on='sid')
# Out:
#       sid  eid_x  year      aired  eid_y         tid  \
# 0       3     20  1977 1978-05-20     18  1978042211
# 1       3     20  1977 1978-05-20     18   197804229
# 2       3     20  1977 1978-05-20     18   197804226
# 3       3     20  1977 1978-05-20     19   197805138
# 4       3     20  1977 1978-05-20     19   197805137
# ...   ...    ...   ...        ...    ...         ...
# 1288    3      9  1977 1978-01-21      3  1977101515
# 1289    3      9  1977 1978-01-21      3  1977101514
# 1290    3      9  1977 1978-01-21      3   197710157
# 1291    3      9  1977 1978-01-21      3   197710158
# 1292    3      9  1977 1978-01-21      3   197710154
#
#                                          title titleType
# 0                               Troff 'n' Brew    Sketch
# 1                                   Love Story    Sketch
# 2                          Dancing in the Dark    Sketch
# 3                                   Pet Peeves    Sketch
# 4                                 Nick Springs    Sketch
# ...                                        ...       ...
# 1288                          Funeral Magician    Sketch
# 1289                    The Playboy Philosophy    Sketch
# 1290                                  X-Police    Sketch
# 1291                 Circular Bed Sex Research    Sketch
# 1292  Planet of the Men vs Planet of the Women    Sketch
#
# [1293 rows x 8 columns]

# %% [markdown]
# Then we extract only the relevant sketches

# %% [markdown]
# We add a new column for the year

# %% [markdown]
# Then we extract only the relevant sketches

# %% [markdown]
# ## For each season, compute the average number of top 1000 voters

# %%
ratings = pd.read_csv('https://github.com/gdv/foundationsCS/raw/main/students/ex-data/snldb/snl_rating.csv')
ratings.head()
# Out:
#    sid  eid  1  10  2  3  4  5   6   7  ...  Males Aged 45+_avg  \
# 0    7    1  0   3  0  0  5  2  10   4  ...                 7.2
# 1   10    1  2   4  0  2  0  4   5   1  ...                 7.3
# 2    6   13  0   3  0  0  1  0   2   9  ...                 7.8
# 3    2    1  0   8  0  2  1  7   8  15  ...                 7.1
# 4    3   20  0   6  0  2  1  3   4  13  ...                 6.9
#
#    Males under 18  Males under 18_avg  Males_avg  Non-US users  \
# 0               0                 NaN        7.1             6
# 1               0                 NaN        6.1             7
# 2               0                 NaN        7.9             5
# 3               0                 NaN        7.2            12
# 4               0                 NaN        7.1             7
#
#    Non-US users_avg  Top 1000 voters  Top 1000 voters_avg  US users  \
# 0               6.4               10                  6.4        22
# 1               5.4                7                  6.4        13
# 2               7.7                9                  7.4        17
# 3               7.4               15                  6.7        33
# 4               7.3               14                  7.3        21
#
#    US users_avg
# 0           6.8
# 1           6.6
# 2           7.7
# 3           6.9
# 4           6.8
#
# [5 rows x 50 columns]

# %%
ratings.groupby('sid')['Top 1000 voters_avg'].mean()
# Out:
# sid
# 1     7.091667
# 2     7.365217
# 3     7.065000
# 4     6.825000
# 5     6.355000
# 6     5.969231
# 7     6.320000
# 8     6.535000
# 9     5.952632
# 10    5.644444
# 11    5.733333
# 12    6.230000
# 13    5.346154
# 14    5.550000
# 15    5.215000
# 16    5.825000
# 17    6.615000
# 18    5.975000
# 19    5.625000
# 20    6.475000
# 21    6.610000
# 22    5.295000
# 23    5.045000
# 24    5.463158
# 25    5.775000
# 26    5.460000
# 27    5.380000
# 28    5.300000
# 29    5.375000
# 30    5.710000
# 31    6.036842
# 32    6.570000
# 33    6.941667
# 34    6.604545
# 35    6.409091
# 36    6.586364
# 37    6.740909
# 38    6.776190
# 39    6.985714
# 40    6.785714
# 41    6.809524
# 42    7.061538
# Name: Top 1000 voters_avg, dtype: float64

# %% [markdown]
# ##  For each season, compute the difference between the maximum and the minimum of `US users_avg`

# %% [markdown]
# First we extract the max and min rating for each season. Since we will merge the resulting tables by using the `sid` column, the `merge` is simpler if both dataframes retain the `sid` column (that is, it does not become part of the index).

# %%
ratings.iloc[ratings.groupby('sid', as_index=False)['US users_avg'].idxmax()['US users_avg']][['sid','US users_avg']]
# Out:
#      sid  US users_avg
# 109    1           8.8
# 51     2           8.1
# 26     3           8.8
# 130    4           8.0
# 24     5           8.1
# 64     6           8.0
# 157    7           8.3
# 798    8           9.1
# 796    9           7.6
# 144   10           8.3
# 766   11           6.8
# 658   12           8.9
# 667   13           7.3
# 627   14           7.4
# 669   15           7.2
# 761   16           7.8
# 700   17           8.6
# 730   18           7.7
# 722   19           7.2
# 609   20           8.1
# 415   21           8.8
# 435   22           7.8
# 545   23           7.7
# 419   24           7.2
# 468   25           8.4
# 446   26           7.4
# 580   27           7.5
# 507   28           6.6
# 519   29           7.1
# 282   30           6.5
# 329   31           8.2
# 353   32           8.5
# 405   33           7.6
# 381   34           7.8
# 359   35           9.1
# 764   36           7.9
# 186   37           8.3
# 220   38           8.3
# 246   39           8.9
# 214   40           8.3
# 265   41           8.0
# 80    42           8.0

# %%
maxmin_df= pd.merge(ratings.iloc[ratings.groupby('sid', as_index=False)['US users_avg'].idxmax()['US users_avg']][['sid','US users_avg']],
         ratings.iloc[ratings.groupby('sid', as_index=False)['US users_avg'].idxmin()['US users_avg']][['sid','US users_avg']],
         on='sid',
         suffixes=['_max', '_min'])
maxmin_df['differenza']= maxmin_df['US users_avg_max']-maxmin_df['US users_avg_min']
maxmin_df
# Out:
#     sid  US users_avg_max  US users_avg_min  differenza
# 0     1               8.8               5.1         3.7
# 1     2               8.1               6.4         1.7
# 2     3               8.8               6.3         2.5
# 3     4               8.0               6.1         1.9
# 4     5               8.1               5.3         2.8
# 5     6               8.0               5.7         2.3
# 6     7               8.3               5.7         2.6
# 7     8               9.1               5.9         3.2
# 8     9               7.6               6.4         1.2
# 9    10               8.3               5.9         2.4
# 10   11               6.8               4.2         2.6
# 11   12               8.9               5.3         3.6
# 12   13               7.3               5.3         2.0
# 13   14               7.4               5.3         2.1
# 14   15               7.2               4.1         3.1
# 15   16               7.8               4.3         3.5
# 16   17               8.6               5.2         3.4
# 17   18               7.7               5.0         2.7
# 18   19               7.2               2.7         4.5
# 19   20               8.1               5.5         2.6
# 20   21               8.8               5.8         3.0
# 21   22               7.8               2.5         5.3
# 22   23               7.7               3.4         4.3
# 23   24               7.2               2.6         4.6
# 24   25               8.4               3.3         5.1
# 25   26               7.4               4.3         3.1
# 26   27               7.5               4.9         2.6
# 27   28               6.6               3.0         3.6
# 28   29               7.1               3.1         4.0
# 29   30               6.5               2.4         4.1
# 30   31               8.2               4.4         3.8
# 31   32               8.5               4.9         3.6
# 32   33               7.6               6.2         1.4
# 33   34               7.8               5.9         1.9
# 34   35               9.1               4.2         4.9
# 35   36               7.9               5.7         2.2
# 36   37               8.3               5.7         2.6
# 37   38               8.3               4.2         4.1
# 38   39               8.9               5.8         3.1
# 39   40               8.3               5.6         2.7
# 40   41               8.0               3.6         4.4
# 41   42               8.0               5.5         2.5
