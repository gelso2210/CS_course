# %% [markdown]
# <a href="https://colab.research.google.com/github/gelso2210/CS_course/blob/main/fifa_ex.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
'''
    Replace Value and Wage with actual numbers
    Check if there are any missing values
    Which teams have the most players?
    Which team pays the largest total wages?
    Which team pays the largest average wage?
    How many players have exactly one preferred position?
    How many players have at least three preferred positions?
    Which are 20 most paid players that have exactly one preferred position?
'''
# Out:
# '\n    Replace Value and Wage with actual numbers\n    Check if there are any missing values\n    Which teams have the most players?\n    Which team pays the largest total wages?\n    Which team pays the largest average wage?\n    How many players have exactly one preferred position?\n    How many players have at least three preferred positions?\n    Which are 20 most paid players that have exactly one preferred position?\n'

# %%
compl_df= pd.read_csv("CompleteDataset.csv")
player_df= pd.read_csv("PlayerAttributeData.csv")
pers_player_df= pd.read_csv("PlayerPersonalData.csv")
pos_player_df= pd.read_csv("PlayerPlayingPositionData.csv")
# Out:
# <ipython-input-151-be3a8799d1d7>:1: DtypeWarning: Columns (23,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   compl_df= pd.read_csv("CompleteDataset.csv")
# <ipython-input-151-be3a8799d1d7>:2: DtypeWarning: Columns (11,24) have mixed types. Specify dtype option on import or set low_memory=False.
#   player_df= pd.read_csv("PlayerAttributeData.csv")

# %% [markdown]
# 1. Convert to real number

# %%
def human_to_int(s :str)-> int:
  s=s.replace("€","")
  if "M" in s:
    multiplier= 1000000
  elif "K" in s:
    multiplier= 1000
  else:
    multiplier=1
  return int(float(s[:-1])*multiplier)



print(human_to_int("€565K"))
print(human_to_int("€5.6M"))
print(human_to_int("€56M"))
# Out:
# 565000
# 5600000
# 56000000

# %%
import re

def human_to_int(s :str)-> int:
  m= re.search(r".([\d\.]+)([KMG]?)", s)   #".[\d\.]+"          \d+(\.\d+)?
  if m.group(2)=='M':
    mult= 1000000
  elif m.group(2)=='K':
    mult= 1000
  else:
    mult= 1
  return int(float(m.group(1))*mult)


pers_player_df["Value"]=pers_player_df["Value"].apply(human_to_int)
pers_player_df["Wage"]=pers_player_df["Wage"].apply(human_to_int)
pers_player_df.head()

'''
sol prof


import re
human_to_int_re = re.compile('.(?P<amount>\d+\.{0,1}\d*)(?P<unit>\w{0,1})')

def unit_to_mult(unit):
    if unit == 'G':
        return 1000000000
    if unit == 'M':
        return 1000000
    if unit == 'K':
        return 1000
    return 1

def to_numeric(elem):
    m = human_to_int_re.search(elem)
    unit = m.group('unit')
    mult = unit_to_mult(unit)
    amount = float(m.group('amount'))
    return int(amount * mult)

'''
# Out:
# "\nsol prof\n\n\nimport re\nhuman_to_int_re = re.compile('.(?P<amount>\\d+\\.{0,1}\\d*)(?P<unit>\\w{0,1})')\n\ndef unit_to_mult(unit):\n    if unit == 'G':\n        return 1000000000\n    if unit == 'M':\n        return 1000000\n    if unit == 'K':\n        return 1000\n    return 1\n\ndef to_numeric(elem):\n    m = human_to_int_re.search(elem)\n    unit = m.group('unit')\n    mult = unit_to_mult(unit)\n    amount = float(m.group('amount'))\n    return int(amount * mult)\n\n"

# %% [markdown]
# 2. Check missing values

# %%
mask=  compl_df.isna().sum(axis=1)>0
compl_df[mask]
# Out:
#        Unnamed: 0           Name  Age  \
# 4               4       M. Neuer   31
# 6               6         De Gea   26
# 12             12    T. Courtois   25
# 18             18      G. Buffon   39
# 20             20       J. Oblak   24
# ...           ...            ...  ...
# 17945       17945      A. Dillon   20
# 17949       17949  M. McElhinney   19
# 17951       17951       M. Hurst   21
# 17976       17976      A. Kelsey   17
# 17977       17977  B. Richardson   47
#
#                                                  Photo          Nationality  \
# 4      https://cdn.sofifa.org/48/18/players/167495.png              Germany
# 6      https://cdn.sofifa.org/48/18/players/193080.png                Spain
# 12     https://cdn.sofifa.org/48/18/players/192119.png              Belgium
# 18       https://cdn.sofifa.org/48/18/players/1179.png                Italy
# 20     https://cdn.sofifa.org/48/18/players/200389.png             Slovenia
# ...

# %%
print(compl_df.isna().sum())
print(player_df.isna().sum())
print(pers_player_df.isna().sum())
print(pos_player_df.isna().sum())
print("NULL VALUES ************************")
print(compl_df.isnull().sum() )
print(player_df.isnull().sum())
print(pers_player_df.isnull().sum())
print(pos_player_df.isnull().sum())
# Out:
# Unnamed: 0        0
# Name              0
# Age               0
# Photo             0
# Nationality       0
#                ...
# RM             2029
# RS             2029
# RW             2029
# RWB            2029
# ST             2029
# Length: 75, dtype: int64
# Unnamed: 0            0
# Acceleration          0
# Aggression            0
# Agility               0
# Balance               0
# Ball control          0
# Composure             0
# Crossing              0
# Curve                 0
# Dribbling             0
# Finishing             0
# Free kick accuracy    0
# GK diving             0
# GK handling           0
# GK kicking            0
# GK positioning        0
# GK reflexes           0
# Heading accuracy      0
# ID                    0
# Interceptions         0
# Jumping               0
# Long passing          0
# Long shots            0
# Marking               0
# Penalties             0
# Positioning           0
# Reactions             0
# Short passing         0
# ...

# %% [markdown]
# 3. Which teams have the most players?

# %%
compl_df["Club"].value_counts().sort_values(ascending=False).head(20)

pers_player_df.groupby('Club')['Club'].count().idxmax()
# Out:
# 'Villarreal CF'

# %%
pers_player_df["Club"].value_counts().sort_values(ascending=False).head(20)
# Out:
# Club
# Villarreal CF                35
# UD Las Palmas                34
# Manchester United            34
# Olympique Lyonnais           34
# OGC Nice                     34
# FC Nantes                    34
# Borussia Dortmund            34
# VfL Wolfsburg                34
# Newcastle United             33
# FC Augsburg                  33
# Bournemouth                  33
# Hamburger SV                 33
# Stoke City                   33
# RC Deportivo de La Coruña    33
# Chelsea                      33
# AS Monaco                    33
# Málaga CF                    33
# Crystal Palace               33
# ES Troyes AC                 33
# Brighton & Hove Albion       33
# Name: count, dtype: int64

# %% [markdown]
# 3. Which team pays the largest total wages?

# %%
pers_player_df.groupby("Club")["Wage"].sum().sort_values(ascending=False).head(20)
# Out:
# Club
# FC Barcelona           4792000
# Real Madrid CF         4751000
# Manchester United      3653000
# Chelsea                3537000
# FC Bayern Munich       3273000
# Juventus               3165000
# Manchester City        3152000
# Arsenal                3007000
# Liverpool              2664000
# Everton                2499000
# Paris Saint-Germain    2198000
# Tottenham Hotspur      2179000
# West Ham United        1935000
# Milan                  1814000
# Borussia Dortmund      1705000
# Southampton            1689000
# Napoli                 1624000
# Roma                   1618000
# Atlético Madrid        1581000
# Leicester City         1423000
# Name: Wage, dtype: int64

# %% [markdown]
# 4. Which team pays the largest average wage?

# %%
pers_player_df.groupby("Club")["Wage"].mean().sort_values(ascending=False).head(20)
# Out:
# Club
# FC Barcelona           191680.000000
# Real Madrid CF         182730.769231
# FC Bayern Munich       125884.615385
# Juventus               121730.769231
# Manchester United      107441.176471
# Chelsea                107181.818182
# Manchester City         95515.151515
# Arsenal                 91121.212121
# Liverpool               83250.000000
# Paris Saint-Germain     78500.000000
# Everton                 75727.272727
# Tottenham Hotspur       68093.750000
# Milan                   62551.724138
# Napoli                  62461.538462
# West Ham United         60468.750000
# Roma                    59925.925926
# Inter                   53440.000000
# Southampton             51181.818182
# Borussia Dortmund       50147.058824
# Atlético Madrid         49406.250000
# Name: Wage, dtype: float64

# %% [markdown]
# 5. How many players have exactly one preferred position?

# %%
compl_df.loc[compl_df["Preferred Positions"].str.split(" ").apply(len)==2]#.shape[0]
# Out:
#        Unnamed: 0            Name  Age  \
# 1               1        L. Messi   30
# 2               2          Neymar   25
# 3               3       L. Suárez   30
# 4               4        M. Neuer   31
# 5               5  R. Lewandowski   28
# ...           ...             ...  ...
# 17975       17975    T. Käßemodel   28
# 17976       17976       A. Kelsey   17
# 17977       17977   B. Richardson   47
# 17978       17978        J. Young   17
# 17979       17979    J. Lundstram   18
#
#                                                  Photo Nationality  \
# 1      https://cdn.sofifa.org/48/18/players/158023.png   Argentina
# 2      https://cdn.sofifa.org/48/18/players/190871.png      Brazil
# 3      https://cdn.sofifa.org/48/18/players/176580.png     Uruguay
# 4      https://cdn.sofifa.org/48/18/players/167495.png     Germany
# 5      https://cdn.sofifa.org/48/18/players/188545.png      Poland
# ...                                                ...         ...
# ...

# %%
compl_df['PP List'] = compl_df['Preferred Positions'].apply(str.split)
print(len([x for x in compl_df['PP List'] if len(x) == 1]))
# better mine but split takes default any whitespace
# Out:
# 9738

# %% [markdown]
# 6. How many players have at least three preferred positions?

# %%
compl_df.loc[compl_df["Preferred Positions"].str.split(" ").apply(len)>=4, ["Name", "Preferred Positions"]]
# Out:
#                  Name Preferred Positions
# 11       K. De Bruyne          RM CM CAM
# 13         A. Sánchez        RM LW ST LM
# 21       A. Griezmann           LW RW ST
# 22             Thiago         CDM CAM CM
# 36         C. Eriksen          LM RM CAM
# ...               ...                 ...
# 17844       M. Stingl           RM LM RB
# 17848     S. Yomesaka          CM CAM LM
# 17877  E. Mason-Clark          ST RM CAM
# 17971        R. White           ST RM LM
# 17972       A. Conway       CB LW LWB LB
#
# [2345 rows x 2 columns]

# %% [markdown]
# 7.  Which are 20 most paid players that have exactly one preferred position?

# %%
pd.set_option('display.max_columns', None)
def human_to_int(s :str)-> int:
  m= re.search(r".([\d\.]+)([KMG]?)", s)   #".[\d\.]+"          \d+(\.\d+)?
  if m.group(2)=='M':
    mult= 1000000
  elif m.group(2)=='K':
    mult= 1000
  else:
    mult= 1
  return int(float(m.group(1))*mult)


compl_df["Value"]=compl_df["Value"].apply(human_to_int)
compl_df["Wage"]=compl_df["Wage"].apply(human_to_int)

# %%
one_preferred_df= compl_df.loc[compl_df["Preferred Positions"].str.split(" ").apply(len)==2]

# %%
one_preferred_df.sort_values("Wage", ascending=False).head(20)
# Out:
#     Unnamed: 0            Name  Age  \
# 1            1        L. Messi   30
# 3            3       L. Suárez   30
# 15          15         G. Bale   27
# 5            5  R. Lewandowski   28
# 16          16       S. Agüero   29
# 10          10    Sergio Ramos   31
# 64          64      K. Benzema   29
# 7            7       E. Hazard   26
# 2            2          Neymar   25
# 41          41      I. Rakitić   29
# 9            9      G. Higuaín   29
# 39          39         Marcelo   29
# 44          44           Piqué   30
# 31          31  Z. Ibrahimović   35
# 58          58     Diego Costa   28
# 4            4        M. Neuer   31
# 17          17    G. Chiellini   32
# 6            6          De Gea   26
# 80          80      Jordi Alba   28
# 25          25      J. Boateng   28
#
#                                               Photo Nationality  \
# 1   https://cdn.sofifa.org/48/18/players/158023.png   Argentina
# ...
